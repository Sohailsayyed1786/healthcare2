# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv(r"C:\Users\admin\Downloads\heart+failure+clinical+records (1)\heart_failure_clinical_records_dataset.csv")

# %%
df
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.corr()
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# time                     -0.224068 -0.141414                 -0.009346
# ...

# %%
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %% [markdown]
# # Plot histograms for numerical features

# %%
numerical_features = ['age', 'creatinine_phosphokinase', 'ejection_fraction', 'platelets', 'serum_creatinine', 'serum_sodium', 'time']
df[numerical_features].hist(bins=15, figsize=(15, 10), layout=(3, 3))
plt.suptitle('Distribution of Numerical Features')
plt.show()

# %% [markdown]
# # Correlation_Matrix

# %%
plt.figure(figsize=(12, 8))
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # BOX_PLOT_FOR_NUMERICAL_FEATURES

# %%
plt.figure(figsize=(15, 10))
for i, feature in enumerate(numerical_features):
    plt.subplot(3, 3, i+1)
    sns.boxplot(x='DEATH_EVENT', y=feature, data=df)
    plt.title(f'{feature} by DEATH_EVENT')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Splitting into training and testing part

# %%
from sklearn.model_selection import train_test_split

# All features
features_all = df.drop(columns=['DEATH_EVENT'])
target = df['DEATH_EVENT']

# Serum creatinine and ejection fraction only
features_creatinine_ejection = df[['serum_creatinine', 'ejection_fraction']]

# Split the data into training and testing sets (80-20 split)
X_train_all, X_test_all, y_train, y_test = train_test_split(features_all, target, test_size=0.2, random_state=42)
X_train_creatinine_ejection, X_test_creatinine_ejection = train_test_split(features_creatinine_ejection, test_size=0.2, random_state=42)

# %% [markdown]
# # Model_building

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
def evaluate_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    return accuracy, precision, recall, f1

# %% [markdown]
# # List_Of_Models_Evaluate

# %%
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    
    'Decision Tree': DecisionTreeClassifier(),
    
    'Random Forest': RandomForestClassifier(),
    
    'Support Vector Machine': SVC(probability=True),
    
    'K-Nearest Neighbors': KNeighborsClassifier(),
    
    'Naive Bayes': GaussianNB(),
    
    'Gradient Boosting': GradientBoostingClassifier(),
    
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss')
}

# %% [markdown]
# # Evalute_the_models_with_All_Features

# %%
print("Evaluation with all features:")
for name, model in models.items():
    accuracy, precision, recall, f1= evaluate_model(model, X_train_all, y_train, X_test_all, y_test)
    print(f"{name}: Accuracy={accuracy:.4f}, Precision={precision:.4f}, Recall={recall:.4f}, F1={f1:.4f}")
# Out:
# Evaluation with all features:
# Logistic Regression: Accuracy=0.8000, Precision=0.8824, Recall=0.6000, F1=0.7143
# Decision Tree: Accuracy=0.6667, Precision=0.6471, Recall=0.4400, F1=0.5238
# Random Forest: Accuracy=0.7167, Precision=0.7500, Recall=0.4800, F1=0.5854
# Support Vector Machine: Accuracy=0.5833, Precision=0.0000, Recall=0.0000, F1=0.0000
# K-Nearest Neighbors: Accuracy=0.5333, Precision=0.2857, Recall=0.0800, F1=0.1250
# Naive Bayes: Accuracy=0.7333, Precision=0.9091, Recall=0.4000, F1=0.5556
# C:\Users\admin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Gradient Boosting: Accuracy=0.7333, Precision=0.7647, Recall=0.5200, F1=0.6190
# XGBoost: Accuracy=0.7667, Precision=0.7895, Recall=0.6000, F1=0.6818

# %% [markdown]
# # Evalute_the_models_with_serum creatinine and ejection fraction

# %%
print("\nEvaluation with serum creatinine and ejection fraction:")
for name, model in models.items():
    accuracy, precision, recall, f1= evaluate_model(model, X_train_creatinine_ejection, y_train, X_test_creatinine_ejection, y_test)
    print(f"{name}: Accuracy={accuracy:.4f}, Precision={precision:.4f}, Recall={recall:.4f}, F1={f1:.4f}")
# Out:
# Evaluation with serum creatinine and ejection fraction:
# Logistic Regression: Accuracy=0.6333, Precision=0.6364, Recall=0.2800, F1=0.3889
# Decision Tree: Accuracy=0.6667, Precision=0.6316, Recall=0.4800, F1=0.5455
# Random Forest: Accuracy=0.6833, Precision=0.6667, Recall=0.4800, F1=0.5581
# Support Vector Machine: Accuracy=0.6167, Precision=0.6667, Recall=0.1600, F1=0.2581
# K-Nearest Neighbors: Accuracy=0.7500, Precision=0.7778, Recall=0.5600, F1=0.6512
# Naive Bayes: Accuracy=0.5667, Precision=0.4000, Recall=0.0800, F1=0.1333
# Gradient Boosting: Accuracy=0.6833, Precision=0.6875, Recall=0.4400, F1=0.5366
# XGBoost: Accuracy=0.6833, Precision=0.6667, Recall=0.4800, F1=0.5581
